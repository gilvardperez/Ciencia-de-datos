# %% [markdown]
# <a href="https://colab.research.google.com/github/gilvardperez/Ciencia-de-datos/blob/main/Bootstrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bootstrap es una técnica estadística que permite estimar la distribución de muestreo de un estadístico (como la media o la mediana) mediante el remuestreo con reemplazo de los datos de una muestra. Es especialmente útil cuando la teoría estadística clásica es difícil de aplicar, como en muestras pequeñas o distribuciones desconocidas

# %% [markdown]
# Usos prácticos del bootstrap incluyen:
# •  Estimar intervalos de confianza y errores estándar cuando las fórmulas analíticas son complejas o desconocidas.
#
# •  Validar la robustez de los resultados estadísticos.
#
# •  Comparar distribuciones y realizar pruebas de hipótesis sin asumir una forma específica para la distribución de los datos.

# %% [markdown]
# Bootstrap:
#
# Bootstrap es una técnica de remuestreo que se utiliza para estimar la distribución de una estadística de interés, como la media, la mediana, la desviación estándar, etc., o para calcular intervalos de confianza para estas estadísticas. La idea principal detrás de Bootstrap es generar múltiples muestras (con reemplazo) de los datos originales y luego calcular la estadística de interés en cada una de estas muestras. Al repetir este proceso muchas veces, podemos obtener una distribución de la estadística de interés y, a partir de esta distribución, podemos calcular intervalos de confianza, percentiles, etc.

# %% [markdown]
# Casos de uso de Bootstrap:
#
#     Estimación de intervalos de confianza: Bootstrap es útil cuando queremos obtener intervalos de confianza para estadísticas de muestras pequeñas o cuando las suposiciones de distribución paramétrica no se cumplen.
#
#     Validación de modelos: En la validación cruzada bootstrap (Bootstrap Cross-Validation), se pueden generar múltiples muestras de entrenamiento y prueba para validar modelos predictivos.
#
#     Estimación de sesgo y varianza: Bootstrap también se puede utilizar para estimar el sesgo y la varianza de un estimador.
#
#     Comparación de métodos: Se puede utilizar para comparar diferentes métodos estadísticos o de aprendizaje automático al calcular intervalos de confianza para sus diferencias.
#
#     Estimación de parámetros: Bootstrap se puede aplicar para estimar parámetros en modelos estadísticos cuando los métodos de estimación estándar son difíciles de aplicar o están sesgados.
#
# En resumen, Bootstrap es una herramienta poderosa y versátil en el arsenal de cualquier analista de datos o científico, que proporciona una manera robusta de obtener estimaciones de parámetros y evaluaciones de incertidumbre en una amplia variedad de situaciones.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.utils import resample

# %%
# Cargamos el conjunto de datos Iris
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
iris_df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Definimos una función para realizar bootstrap en la longitud del sépalo
def bootstrap(dataframe, column_name, n=1000):
    means = []
    for _ in range(n):
        sample = resample(dataframe[column_name])
        means.append(sample.mean())
    return means

# %%
# Aplicamos bootstrap a la columna de longitud del sépalo
bootstrap_means = bootstrap(iris_df, 'sepal length (cm)')

# %%
means
# Out:
# []

# %%
# Calculamos el intervalo de confianza del 95%
lower = np.percentile(bootstrap_means, 2.5)
upper = np.percentile(bootstrap_means, 97.5)
print(f"Intervalo de confianza al 95% para la media de la longitud del sépalo: {lower:.2f} - {upper:.2f}")
# Out:
# Intervalo de confianza al 95% para la media de la longitud del sépalo: 5.71 - 5.97

# %% [markdown]
# Forma iterativa

# %%
# Definimos una función para realizar bootstrap en la longitud del sépalo
def bootstrap(dataframe, column_name, n=1000):
    means = []
    for i in range(n):
        sample = resample(dataframe[column_name])
        mean = sample.mean()
        means.append(mean)
        print(f"Iteración {i+1}: Media = {mean:.2f}")
    return means

# Aplicamos bootstrap a la columna de longitud del sépalo
bootstrap_means = bootstrap(iris_df, 'sepal length (cm)')

# Calculamos el intervalo de confianza del 95%
lower = np.percentile(bootstrap_means, 2.5)
upper = np.percentile(bootstrap_means, 97.5)
print(f"\nIntervalo de confianza al 95% para la media de la longitud del sépalo: {lower:.2f} - {upper:.2f}")
# Out:
# Iteración 1: Media = 4.95
# Iteración 2: Media = 5.01
# Iteración 3: Media = 4.91
# Iteración 4: Media = 4.97
# Iteración 5: Media = 4.98
# Iteración 6: Media = 4.91
# Iteración 7: Media = 4.98
# Iteración 8: Media = 5.02
# Iteración 9: Media = 4.87
# Iteración 10: Media = 4.99
# Iteración 11: Media = 4.94
# Iteración 12: Media = 4.94
# Iteración 13: Media = 5.00
# Iteración 14: Media = 4.93
# Iteración 15: Media = 5.00
# Iteración 16: Media = 4.93
# Iteración 17: Media = 4.96
# Iteración 18: Media = 4.93
# Iteración 19: Media = 4.94
# Iteración 20: Media = 4.91
# Iteración 21: Media = 4.98
# Iteración 22: Media = 4.98
# Iteración 23: Media = 4.99
# Iteración 24: Media = 4.92
# Iteración 25: Media = 4.98
# Iteración 26: Media = 4.98
# Iteración 27: Media = 4.99
# Iteración 28: Media = 4.90
# Iteración 29: Media = 4.93
# Iteración 30: Media = 4.99
# Iteración 31: Media = 4.91
# Iteración 32: Media = 4.94
# Iteración 33: Media = 5.01
# Iteración 34: Media = 4.97
# Iteración 35: Media = 5.02
# Iteración 36: Media = 4.95
# Iteración 37: Media = 4.97
# Iteración 38: Media = 4.96
# Iteración 39: Media = 4.94
# Iteración 40: Media = 4.95
# Iteración 41: Media = 4.96
# Iteración 42: Media = 4.92
# Iteración 43: Media = 5.05
# Iteración 44: Media = 4.90
# Iteración 45: Media = 5.00
# Iteración 46: Media = 4.98
# Iteración 47: Media = 4.96
# Iteración 48: Media = 5.00
# Iteración 49: Media = 4.94
# Iteración 50: Media = 4.96
# Iteración 51: Media = 4.90
# Iteración 52: Media = 4.97
# Iteración 53: Media = 4.93
# Iteración 54: Media = 4.92
# Iteración 55: Media = 4.98
# Iteración 56: Media = 4.91
# Iteración 57: Media = 4.96
# Iteración 58: Media = 4.99
# Iteración 59: Media = 4.88
# Iteración 60: Media = 4.94
# Iteración 61: Media = 4.96
# Iteración 62: Media = 5.00
# Iteración 63: Media = 4.92
# Iteración 64: Media = 4.97
# Iteración 65: Media = 4.91
# Iteración 66: Media = 4.92
# Iteración 67: Media = 4.97
# Iteración 68: Media = 4.91
# Iteración 69: Media = 4.99
# Iteración 70: Media = 4.93
# Iteración 71: Media = 5.05
# Iteración 72: Media = 4.99
# Iteración 73: Media = 4.95
# Iteración 74: Media = 4.96
# Iteración 75: Media = 5.00
# Iteración 76: Media = 4.98
# Iteración 77: Media = 4.91
# Iteración 78: Media = 4.93
# Iteración 79: Media = 4.94
# Iteración 80: Media = 4.90
# Iteración 81: Media = 4.90
# Iteración 82: Media = 4.95
# Iteración 83: Media = 4.98
# Iteración 84: Media = 4.96
# Iteración 85: Media = 4.96
# Iteración 86: Media = 4.96
# Iteración 87: Media = 5.01
# Iteración 88: Media = 5.06
# Iteración 89: Media = 5.03
# Iteración 90: Media = 4.97
# Iteración 91: Media = 4.97
# Iteración 92: Media = 4.93
# Iteración 93: Media = 4.97
# Iteración 94: Media = 4.97
# Iteración 95: Media = 5.00
# Iteración 96: Media = 4.98
# Iteración 97: Media = 4.92
# Iteración 98: Media = 4.89
# Iteración 99: Media = 4.97
# Iteración 100: Media = 5.00
# Iteración 101: Media = 4.95
# Iteración 102: Media = 5.00
# Iteración 103: Media = 5.00
# Iteración 104: Media = 4.98
# Iteración 105: Media = 4.97
# Iteración 106: Media = 4.91
# Iteración 107: Media = 5.00
# Iteración 108: Media = 4.99
# Iteración 109: Media = 4.92
# Iteración 110: Media = 4.98
# Iteración 111: Media = 4.99
# Iteración 112: Media = 4.95
# Iteración 113: Media = 4.89
# Iteración 114: Media = 4.89
# Iteración 115: Media = 5.00
# Iteración 116: Media = 5.00
# Iteración 117: Media = 4.97
# Iteración 118: Media = 4.97
# Iteración 119: Media = 4.89
# Iteración 120: Media = 4.95
# Iteración 121: Media = 4.89
# Iteración 122: Media = 4.89
# Iteración 123: Media = 5.03
# Iteración 124: Media = 4.91
# Iteración 125: Media = 4.96
# Iteración 126: Media = 5.01
# Iteración 127: Media = 4.90
# Iteración 128: Media = 5.01
# Iteración 129: Media = 4.93
# Iteración 130: Media = 4.96
# Iteración 131: Media = 4.91
# Iteración 132: Media = 4.94
# Iteración 133: Media = 5.00
# Iteración 134: Media = 4.99
# Iteración 135: Media = 4.94
# Iteración 136: Media = 4.92
# Iteración 137: Media = 4.90
# Iteración 138: Media = 4.96
# Iteración 139: Media = 4.91
# Iteración 140: Media = 4.96
# Iteración 141: Media = 4.96
# Iteración 142: Media = 5.00
# Iteración 143: Media = 4.97
# Iteración 144: Media = 4.91
# Iteración 145: Media = 5.02
# Iteración 146: Media = 5.03
# Iteración 147: Media = 4.95
# Iteración 148: Media = 4.95
# Iteración 149: Media = 4.95
# Iteración 150: Media = 4.93
# Iteración 151: Media = 5.05
# Iteración 152: Media = 4.90
# Iteración 153: Media = 4.92
# Iteración 154: Media = 4.96
# Iteración 155: Media = 4.89
# Iteración 156: Media = 4.92
# Iteración 157: Media = 4.96
# Iteración 158: Media = 4.95
# Iteración 159: Media = 4.97
# Iteración 160: Media = 4.98
# Iteración 161: Media = 5.01
# Iteración 162: Media = 4.99
# Iteración 163: Media = 5.00
# Iteración 164: Media = 4.97
# Iteración 165: Media = 4.96
# Iteración 166: Media = 4.96
# Iteración 167: Media = 4.94
# Iteración 168: Media = 4.96
# Iteración 169: Media = 4.98
# Iteración 170: Media = 4.97
# Iteración 171: Media = 5.01
# Iteración 172: Media = 4.82
# Iteración 173: Media = 4.87
# Iteración 174: Media = 4.96
# Iteración 175: Media = 4.93
# Iteración 176: Media = 4.99
# Iteración 177: Media = 4.99
# Iteración 178: Media = 5.02
# Iteración 179: Media = 5.03
# Iteración 180: Media = 4.97
# Iteración 181: Media = 5.02
# Iteración 182: Media = 4.97
# Iteración 183: Media = 4.98
# Iteración 184: Media = 4.99
# Iteración 185: Media = 5.02
# Iteración 186: Media = 4.96
# Iteración 187: Media = 4.94
# Iteración 188: Media = 4.89
# Iteración 189: Media = 4.97
# Iteración 190: Media = 4.95
# Iteración 191: Media = 4.99
# Iteración 192: Media = 4.92
# Iteración 193: Media = 4.94
# Iteración 194: Media = 4.99
# Iteración 195: Media = 4.98
# Iteración 196: Media = 4.93
# Iteración 197: Media = 4.93
# Iteración 198: Media = 4.96
# Iteración 199: Media = 4.97
# Iteración 200: Media = 5.02
# Iteración 201: Media = 4.95
# Iteración 202: Media = 4.99
# Iteración 203: Media = 4.98
# Iteración 204: Media = 4.96
# Iteración 205: Media = 4.92
# Iteración 206: Media = 4.87
# Iteración 207: Media = 4.92
# Iteración 208: Media = 4.95
# Iteración 209: Media = 4.89
# Iteración 210: Media = 4.94
# Iteración 211: Media = 4.94
# Iteración 212: Media = 5.02
# Iteración 213: Media = 4.93
# Iteración 214: Media = 4.93
# Iteración 215: Media = 4.97
# Iteración 216: Media = 4.94
# Iteración 217: Media = 5.00
# Iteración 218: Media = 4.94
# Iteración 219: Media = 4.95
# Iteración 220: Media = 4.99
# Iteración 221: Media = 4.98
# Iteración 222: Media = 4.92
# Iteración 223: Media = 4.95
# Iteración 224: Media = 4.94
# Iteración 225: Media = 5.02
# Iteración 226: Media = 4.93
# Iteración 227: Media = 4.97
# Iteración 228: Media = 4.91
# Iteración 229: Media = 4.98
# Iteración 230: Media = 4.92
# Iteración 231: Media = 4.91
# Iteración 232: Media = 4.92
# Iteración 233: Media = 4.93
# Iteración 234: Media = 4.95
# Iteración 235: Media = 5.00
# Iteración 236: Media = 4.85
# Iteración 237: Media = 4.90
# Iteración 238: Media = 4.94
# Iteración 239: Media = 4.98
# Iteración 240: Media = 4.96
# Iteración 241: Media = 4.96
# Iteración 242: Media = 4.97
# Iteración 243: Media = 4.91
# Iteración 244: Media = 4.95
# Iteración 245: Media = 5.01
# Iteración 246: Media = 5.01
# Iteración 247: Media = 4.88
# Iteración 248: Media = 5.00
# Iteración 249: Media = 4.93
# Iteración 250: Media = 4.94
# Iteración 251: Media = 5.06
# Iteración 252: Media = 4.95
# Iteración 253: Media = 4.94
# Iteración 254: Media = 4.93
# Iteración 255: Media = 4.85
# Iteración 256: Media = 4.92
# Iteración 257: Media = 5.01
# Iteración 258: Media = 4.97
# Iteración 259: Media = 5.02
# Iteración 260: Media = 4.91
# Iteración 261: Media = 4.89
# Iteración 262: Media = 4.96
# Iteración 263: Media = 4.96
# Iteración 264: Media = 4.93
# Iteración 265: Media = 4.91
# Iteración 266: Media = 4.99
# Iteración 267: Media = 4.95
# Iteración 268: Media = 4.95
# Iteración 269: Media = 4.94
# Iteración 270: Media = 4.98
# Iteración 271: Media = 4.90
# Iteración 272: Media = 4.92
# Iteración 273: Media = 4.97
# Iteración 274: Media = 4.90
# Iteración 275: Media = 5.01
# Iteración 276: Media = 4.94
# Iteración 277: Media = 4.95
# Iteración 278: Media = 4.96
# Iteración 279: Media = 4.91
# Iteración 280: Media = 4.92
# Iteración 281: Media = 4.91
# Iteración 282: Media = 4.98
# Iteración 283: Media = 4.88
# Iteración 284: Media = 4.99
# Iteración 285: Media = 4.96
# Iteración 286: Media = 4.96
# Iteración 287: Media = 4.94
# Iteración 288: Media = 4.93
# Iteración 289: Media = 4.97
# Iteración 290: Media = 4.95
# Iteración 291: Media = 5.00
# Iteración 292: Media = 4.93
# Iteración 293: Media = 4.90
# Iteración 294: Media = 4.97
# Iteración 295: Media = 4.91
# Iteración 296: Media = 4.88
# Iteración 297: Media = 4.92
# Iteración 298: Media = 4.95
# Iteración 299: Media = 4.99
# Iteración 300: Media = 4.99
# Iteración 301: Media = 4.89
# Iteración 302: Media = 4.95
# Iteración 303: Media = 5.01
# Iteración 304: Media = 4.91
# Iteración 305: Media = 4.90
# Iteración 306: Media = 4.99
# Iteración 307: Media = 4.93
# Iteración 308: Media = 4.98
# Iteración 309: Media = 4.92
# Iteración 310: Media = 4.90
# Iteración 311: Media = 4.99
# Iteración 312: Media = 4.94
# Iteración 313: Media = 4.84
# Iteración 314: Media = 5.02
# Iteración 315: Media = 4.95
# Iteración 316: Media = 4.93
# Iteración 317: Media = 4.97
# Iteración 318: Media = 5.00
# Iteración 319: Media = 4.98
# Iteración 320: Media = 4.91
# Iteración 321: Media = 4.95
# Iteración 322: Media = 4.98
# Iteración 323: Media = 4.91
# Iteración 324: Media = 4.99
# Iteración 325: Media = 5.03
# Iteración 326: Media = 4.99
# Iteración 327: Media = 4.94
# Iteración 328: Media = 4.98
# Iteración 329: Media = 4.94
# Iteración 330: Media = 4.96
# Iteración 331: Media = 4.94
# Iteración 332: Media = 4.96
# Iteración 333: Media = 5.01
# Iteración 334: Media = 4.92
# Iteración 335: Media = 4.97
# Iteración 336: Media = 4.91
# Iteración 337: Media = 4.90
# Iteración 338: Media = 4.96
# Iteración 339: Media = 5.00
# Iteración 340: Media = 4.98
# Iteración 341: Media = 4.93
# Iteración 342: Media = 5.02
# Iteración 343: Media = 4.92
# Iteración 344: Media = 4.99
# Iteración 345: Media = 4.93
# Iteración 346: Media = 5.00
# Iteración 347: Media = 5.02
# Iteración 348: Media = 4.94
# Iteración 349: Media = 4.98
# Iteración 350: Media = 4.90
# Iteración 351: Media = 4.95
# Iteración 352: Media = 4.89
# Iteración 353: Media = 4.97
# Iteración 354: Media = 4.95
# Iteración 355: Media = 4.92
# Iteración 356: Media = 4.99
# Iteración 357: Media = 4.86
# Iteración 358: Media = 4.93
# Iteración 359: Media = 4.96
# Iteración 360: Media = 5.04
# Iteración 361: Media = 4.97
# Iteración 362: Media = 4.96
# Iteración 363: Media = 4.95
# Iteración 364: Media = 4.98
# Iteración 365: Media = 4.94
# Iteración 366: Media = 5.02
# Iteración 367: Media = 4.94
# Iteración 368: Media = 5.02
# Iteración 369: Media = 4.97
# Iteración 370: Media = 4.98
# Iteración 371: Media = 5.02
# Iteración 372: Media = 4.97
# Iteración 373: Media = 4.97
# Iteración 374: Media = 4.92
# Iteración 375: Media = 4.93
# Iteración 376: Media = 4.98
# Iteración 377: Media = 4.96
# Iteración 378: Media = 4.97
# Iteración 379: Media = 4.93
# Iteración 380: Media = 4.94
# Iteración 381: Media = 5.04
# Iteración 382: Media = 4.94
# Iteración 383: Media = 4.84
# Iteración 384: Media = 4.99
# Iteración 385: Media = 4.94
# Iteración 386: Media = 4.89
# Iteración 387: Media = 4.97
# Iteración 388: Media = 4.93
# Iteración 389: Media = 5.00
# Iteración 390: Media = 4.88
# Iteración 391: Media = 4.94
# Iteración 392: Media = 4.98
# Iteración 393: Media = 5.01
# Iteración 394: Media = 4.91
# Iteración 395: Media = 4.98
# Iteración 396: Media = 4.97
# Iteración 397: Media = 4.96
# Iteración 398: Media = 4.98
# Iteración 399: Media = 4.97
# Iteración 400: Media = 4.96
# Iteración 401: Media = 4.94
# Iteración 402: Media = 4.93
# Iteración 403: Media = 5.01
# Iteración 404: Media = 4.90
# Iteración 405: Media = 5.01
# Iteración 406: Media = 5.01
# Iteración 407: Media = 4.87
# Iteración 408: Media = 4.95
# Iteración 409: Media = 4.97
# Iteración 410: Media = 5.01
# Iteración 411: Media = 4.90
# Iteración 412: Media = 4.92
# Iteración 413: Media = 4.95
# Iteración 414: Media = 4.93
# Iteración 415: Media = 4.94
# Iteración 416: Media = 4.92
# Iteración 417: Media = 4.96
# Iteración 418: Media = 5.03
# Iteración 419: Media = 4.92
# Iteración 420: Media = 5.00
# Iteración 421: Media = 4.87
# Iteración 422: Media = 5.01
# Iteración 423: Media = 4.94
# Iteración 424: Media = 5.01
# Iteración 425: Media = 4.91
# Iteración 426: Media = 4.91
# Iteración 427: Media = 4.93
# Iteración 428: Media = 4.96
# Iteración 429: Media = 4.87
# Iteración 430: Media = 4.95
# Iteración 431: Media = 5.02
# Iteración 432: Media = 4.93
# Iteración 433: Media = 4.95
# Iteración 434: Media = 4.93
# Iteración 435: Media = 4.96
# Iteración 436: Media = 4.96
# Iteración 437: Media = 4.95
# Iteración 438: Media = 4.91
# Iteración 439: Media = 4.93
# Iteración 440: Media = 4.92
# Iteración 441: Media = 4.84
# Iteración 442: Media = 5.02
# Iteración 443: Media = 4.96
# Iteración 444: Media = 4.97
# Iteración 445: Media = 4.84
# Iteración 446: Media = 5.00
# Iteración 447: Media = 5.02
# Iteración 448: Media = 4.97
# Iteración 449: Media = 5.03
# Iteración 450: Media = 4.94
# Iteración 451: Media = 5.02
# Iteración 452: Media = 4.93
# Iteración 453: Media = 4.89
# Iteración 454: Media = 4.82
# Iteración 455: Media = 4.97
# Iteración 456: Media = 4.92
# Iteración 457: Media = 4.96
# Iteración 458: Media = 4.92
# Iteración 459: Media = 4.90
# Iteración 460: Media = 4.94
# Iteración 461: Media = 4.91
# Iteración 462: Media = 4.92
# Iteración 463: Media = 4.91
# Iteración 464: Media = 4.89
# Iteración 465: Media = 4.95
# Iteración 466: Media = 4.93
# Iteración 467: Media = 4.96
# Iteración 468: Media = 4.93
# Iteración 469: Media = 4.93
# Iteración 470: Media = 4.92
# Iteración 471: Media = 5.00
# Iteración 472: Media = 4.94
# Iteración 473: Media = 4.98
# Iteración 474: Media = 4.94
# Iteración 475: Media = 4.93
# Iteración 476: Media = 4.97
# Iteración 477: Media = 4.96
# Iteración 478: Media = 5.00
# Iteración 479: Media = 4.92
# Iteración 480: Media = 5.01
# Iteración 481: Media = 4.99
# Iteración 482: Media = 4.99
# Iteración 483: Media = 4.93
# Iteración 484: Media = 5.04
# Iteración 485: Media = 4.98
# Iteración 486: Media = 4.94
# Iteración 487: Media = 4.94
# Iteración 488: Media = 4.95
# Iteración 489: Media = 4.93
# Iteración 490: Media = 4.94
# Iteración 491: Media = 4.93
# Iteración 492: Media = 4.95
# Iteración 493: Media = 4.90
# Iteración 494: Media = 4.97
# Iteración 495: Media = 4.98
# Iteración 496: Media = 5.00
# Iteración 497: Media = 5.01
# Iteración 498: Media = 4.98
# Iteración 499: Media = 4.99
# Iteración 500: Media = 4.95
# Iteración 501: Media = 4.89
# Iteración 502: Media = 4.94
# Iteración 503: Media = 4.95
# Iteración 504: Media = 4.95
# Iteración 505: Media = 4.98
# Iteración 506: Media = 4.95
# Iteración 507: Media = 4.96
# Iteración 508: Media = 4.98
# Iteración 509: Media = 4.96
# Iteración 510: Media = 4.93
# Iteración 511: Media = 4.93
# Iteración 512: Media = 5.05
# Iteración 513: Media = 4.94
# Iteración 514: Media = 4.94
# Iteración 515: Media = 4.98
# Iteración 516: Media = 4.93
# Iteración 517: Media = 4.99
# Iteración 518: Media = 4.94
# Iteración 519: Media = 4.92
# Iteración 520: Media = 4.97
# Iteración 521: Media = 4.99
# Iteración 522: Media = 4.98
# Iteración 523: Media = 4.95
# Iteración 524: Media = 4.93
# Iteración 525: Media = 4.93
# Iteración 526: Media = 5.01
# Iteración 527: Media = 5.01
# Iteración 528: Media = 4.96
# Iteración 529: Media = 4.94
# Iteración 530: Media = 4.99
# Iteración 531: Media = 4.99
# Iteración 532: Media = 4.92
# Iteración 533: Media = 5.01
# Iteración 534: Media = 4.98
# Iteración 535: Media = 4.96
# Iteración 536: Media = 4.89
# Iteración 537: Media = 4.90
# Iteración 538: Media = 4.98
# Iteración 539: Media = 4.97
# Iteración 540: Media = 5.00
# Iteración 541: Media = 4.96
# Iteración 542: Media = 4.94
# Iteración 543: Media = 4.99
# Iteración 544: Media = 4.91
# Iteración 545: Media = 4.92
# Iteración 546: Media = 4.95
# Iteración 547: Media = 4.95
# Iteración 548: Media = 4.91
# Iteración 549: Media = 4.97
# Iteración 550: Media = 4.90
# Iteración 551: Media = 4.91
# Iteración 552: Media = 4.93
# Iteración 553: Media = 4.98
# Iteración 554: Media = 4.93
# Iteración 555: Media = 4.99
# Iteración 556: Media = 4.88
# Iteración 557: Media = 4.91
# Iteración 558: Media = 4.98
# Iteración 559: Media = 4.96
# Iteración 560: Media = 4.98
# Iteración 561: Media = 4.98
# Iteración 562: Media = 5.01
# Iteración 563: Media = 4.91
# Iteración 564: Media = 4.88
# Iteración 565: Media = 4.95
# Iteración 566: Media = 4.96
# Iteración 567: Media = 4.93
# Iteración 568: Media = 4.94
# Iteración 569: Media = 4.97
# Iteración 570: Media = 4.96
# Iteración 571: Media = 4.99
# Iteración 572: Media = 4.95
# Iteración 573: Media = 4.97
# Iteración 574: Media = 5.00
# Iteración 575: Media = 4.94
# Iteración 576: Media = 4.98
# Iteración 577: Media = 4.97
# Iteración 578: Media = 4.90
# Iteración 579: Media = 5.03
# Iteración 580: Media = 4.95
# Iteración 581: Media = 4.92
# Iteración 582: Media = 4.97
# Iteración 583: Media = 4.90
# Iteración 584: Media = 4.89
# Iteración 585: Media = 4.99
# Iteración 586: Media = 4.97
# Iteración 587: Media = 4.98
# Iteración 588: Media = 5.00
# Iteración 589: Media = 4.98
# Iteración 590: Media = 4.97
# Iteración 591: Media = 4.88
# Iteración 592: Media = 4.93
# Iteración 593: Media = 4.99
# Iteración 594: Media = 4.93
# Iteración 595: Media = 5.00
# Iteración 596: Media = 5.00
# Iteración 597: Media = 4.96
# Iteración 598: Media = 4.98
# Iteración 599: Media = 4.91
# Iteración 600: Media = 4.98
# Iteración 601: Media = 4.93
# Iteración 602: Media = 4.98
# Iteración 603: Media = 4.89
# Iteración 604: Media = 4.93
# Iteración 605: Media = 5.00
# Iteración 606: Media = 5.01
# Iteración 607: Media = 4.91
# Iteración 608: Media = 4.98
# Iteración 609: Media = 4.94
# Iteración 610: Media = 4.92
# Iteración 611: Media = 5.04
# Iteración 612: Media = 5.01
# Iteración 613: Media = 4.94
# Iteración 614: Media = 5.03
# Iteración 615: Media = 4.91
# Iteración 616: Media = 5.02
# Iteración 617: Media = 4.94
# Iteración 618: Media = 4.97
# Iteración 619: Media = 5.02
# Iteración 620: Media = 4.94
# Iteración 621: Media = 5.01
# Iteración 622: Media = 4.95
# Iteración 623: Media = 5.01
# Iteración 624: Media = 4.98
# Iteración 625: Media = 4.96
# Iteración 626: Media = 4.99
# Iteración 627: Media = 4.95
# Iteración 628: Media = 4.98
# Iteración 629: Media = 4.96
# Iteración 630: Media = 4.90
# Iteración 631: Media = 4.99
# Iteración 632: Media = 5.02
# Iteración 633: Media = 4.96
# Iteración 634: Media = 4.98
# Iteración 635: Media = 4.91
# Iteración 636: Media = 4.96
# Iteración 637: Media = 4.96
# Iteración 638: Media = 4.94
# Iteración 639: Media = 4.95
# Iteración 640: Media = 4.97
# Iteración 641: Media = 4.91
# Iteración 642: Media = 4.93
# Iteración 643: Media = 4.99
# Iteración 644: Media = 4.92
# Iteración 645: Media = 4.99
# Iteración 646: Media = 4.91
# Iteración 647: Media = 4.93
# Iteración 648: Media = 4.90
# Iteración 649: Media = 4.94
# Iteración 650: Media = 4.92
# Iteración 651: Media = 4.93
# Iteración 652: Media = 4.88
# Iteración 653: Media = 4.98
# Iteración 654: Media = 4.93
# Iteración 655: Media = 5.05
# Iteración 656: Media = 4.97
# Iteración 657: Media = 4.98
# Iteración 658: Media = 4.94
# Iteración 659: Media = 5.04
# Iteración 660: Media = 4.98
# Iteración 661: Media = 4.98
# Iteración 662: Media = 4.98
# Iteración 663: Media = 4.92
# Iteración 664: Media = 4.93
# Iteración 665: Media = 5.00
# Iteración 666: Media = 5.00
# Iteración 667: Media = 4.95
# Iteración 668: Media = 4.89
# Iteración 669: Media = 4.99
# Iteración 670: Media = 4.94
# Iteración 671: Media = 4.96
# Iteración 672: Media = 4.89
# Iteración 673: Media = 5.01
# Iteración 674: Media = 4.99
# Iteración 675: Media = 4.94
# Iteración 676: Media = 4.95
# Iteración 677: Media = 4.98
# Iteración 678: Media = 4.86
# Iteración 679: Media = 4.94
# Iteración 680: Media = 4.90
# Iteración 681: Media = 4.92
# Iteración 682: Media = 4.97
# Iteración 683: Media = 4.91
# Iteración 684: Media = 4.95
# Iteración 685: Media = 4.91
# Iteración 686: Media = 4.94
# Iteración 687: Media = 4.92
# Iteración 688: Media = 4.93
# Iteración 689: Media = 4.94
# Iteración 690: Media = 4.93
# Iteración 691: Media = 4.90
# Iteración 692: Media = 4.84
# Iteración 693: Media = 4.95
# Iteración 694: Media = 4.96
# Iteración 695: Media = 4.99
# Iteración 696: Media = 4.95
# Iteración 697: Media = 4.88
# Iteración 698: Media = 4.89
# Iteración 699: Media = 4.96
# Iteración 700: Media = 4.95
# Iteración 701: Media = 4.92
# Iteración 702: Media = 4.98
# Iteración 703: Media = 4.97
# Iteración 704: Media = 4.97
# Iteración 705: Media = 5.01
# Iteración 706: Media = 5.03
# Iteración 707: Media = 4.93
# Iteración 708: Media = 4.94
# Iteración 709: Media = 4.95
# Iteración 710: Media = 5.02
# Iteración 711: Media = 4.97
# Iteración 712: Media = 4.92
# Iteración 713: Media = 4.97
# Iteración 714: Media = 4.98
# Iteración 715: Media = 5.00
# Iteración 716: Media = 4.90
# Iteración 717: Media = 4.92
# Iteración 718: Media = 5.03
# Iteración 719: Media = 4.94
# Iteración 720: Media = 4.94
# Iteración 721: Media = 4.94
# Iteración 722: Media = 4.94
# Iteración 723: Media = 4.99
# Iteración 724: Media = 4.98
# Iteración 725: Media = 4.99
# Iteración 726: Media = 4.96
# Iteración 727: Media = 4.92
# Iteración 728: Media = 4.93
# Iteración 729: Media = 4.96
# Iteración 730: Media = 4.92
# Iteración 731: Media = 4.96
# Iteración 732: Media = 5.00
# Iteración 733: Media = 5.03
# Iteración 734: Media = 5.07
# Iteración 735: Media = 4.93
# Iteración 736: Media = 4.99
# Iteración 737: Media = 4.89
# Iteración 738: Media = 4.98
# Iteración 739: Media = 4.94
# Iteración 740: Media = 5.05
# Iteración 741: Media = 4.96
# Iteración 742: Media = 4.96
# Iteración 743: Media = 4.91
# Iteración 744: Media = 5.05
# Iteración 745: Media = 4.97
# Iteración 746: Media = 4.92
# Iteración 747: Media = 4.92
# Iteración 748: Media = 4.92
# Iteración 749: Media = 4.95
# Iteración 750: Media = 5.01
# Iteración 751: Media = 5.03
# Iteración 752: Media = 4.92
# Iteración 753: Media = 4.94
# Iteración 754: Media = 4.99
# Iteración 755: Media = 4.88
# Iteración 756: Media = 4.99
# Iteración 757: Media = 4.93
# Iteración 758: Media = 4.91
# Iteración 759: Media = 4.91
# Iteración 760: Media = 4.96
# Iteración 761: Media = 4.96
# Iteración 762: Media = 4.90
# Iteración 763: Media = 4.98
# Iteración 764: Media = 4.96
# Iteración 765: Media = 5.00
# Iteración 766: Media = 4.99
# Iteración 767: Media = 4.95
# Iteración 768: Media = 4.99
# Iteración 769: Media = 4.96
# Iteración 770: Media = 4.98
# Iteración 771: Media = 4.92
# Iteración 772: Media = 4.94
# Iteración 773: Media = 4.92
# Iteración 774: Media = 4.87
# Iteración 775: Media = 4.87
# Iteración 776: Media = 4.96
# Iteración 777: Media = 4.94
# Iteración 778: Media = 4.94
# Iteración 779: Media = 4.99
# Iteración 780: Media = 4.98
# Iteración 781: Media = 4.90
# Iteración 782: Media = 4.94
# Iteración 783: Media = 4.91
# Iteración 784: Media = 4.95
# Iteración 785: Media = 5.02
# Iteración 786: Media = 4.90
# Iteración 787: Media = 4.90
# Iteración 788: Media = 4.92
# Iteración 789: Media = 4.94
# Iteración 790: Media = 4.90
# Iteración 791: Media = 4.90
# Iteración 792: Media = 4.89
# Iteración 793: Media = 4.94
# Iteración 794: Media = 5.02
# Iteración 795: Media = 4.91
# Iteración 796: Media = 4.98
# Iteración 797: Media = 4.93
# Iteración 798: Media = 4.91
# Iteración 799: Media = 4.92
# Iteración 800: Media = 4.92
# Iteración 801: Media = 4.93
# Iteración 802: Media = 4.92
# Iteración 803: Media = 4.99
# Iteración 804: Media = 4.98
# Iteración 805: Media = 4.94
# Iteración 806: Media = 4.93
# Iteración 807: Media = 4.95
# Iteración 808: Media = 4.98
# Iteración 809: Media = 4.93
# Iteración 810: Media = 4.95
# Iteración 811: Media = 4.98
# Iteración 812: Media = 5.02
# Iteración 813: Media = 4.99
# Iteración 814: Media = 4.98
# Iteración 815: Media = 4.89
# Iteración 816: Media = 4.91
# Iteración 817: Media = 4.98
# Iteración 818: Media = 4.96
# Iteración 819: Media = 4.95
# Iteración 820: Media = 5.08
# Iteración 821: Media = 4.89
# Iteración 822: Media = 4.96
# Iteración 823: Media = 4.99
# Iteración 824: Media = 4.92
# Iteración 825: Media = 4.96
# Iteración 826: Media = 5.03
# Iteración 827: Media = 5.01
# Iteración 828: Media = 4.91
# Iteración 829: Media = 4.96
# Iteración 830: Media = 4.95
# Iteración 831: Media = 4.99
# Iteración 832: Media = 4.91
# Iteración 833: Media = 4.87
# Iteración 834: Media = 4.91
# Iteración 835: Media = 4.85
# Iteración 836: Media = 5.03
# Iteración 837: Media = 4.95
# Iteración 838: Media = 5.02
# Iteración 839: Media = 4.97
# Iteración 840: Media = 4.93
# Iteración 841: Media = 4.99
# Iteración 842: Media = 4.92
# Iteración 843: Media = 4.94
# Iteración 844: Media = 4.91
# Iteración 845: Media = 4.94
# Iteración 846: Media = 4.97
# Iteración 847: Media = 4.92
# Iteración 848: Media = 4.90
# Iteración 849: Media = 4.95
# Iteración 850: Media = 4.94
# Iteración 851: Media = 4.96
# Iteración 852: Media = 4.95
# Iteración 853: Media = 4.99
# Iteración 854: Media = 4.93
# Iteración 855: Media = 4.94
# Iteración 856: Media = 4.98
# Iteración 857: Media = 4.97
# Iteración 858: Media = 5.00
# Iteración 859: Media = 4.94
# Iteración 860: Media = 4.99
# Iteración 861: Media = 4.93
# Iteración 862: Media = 4.96
# Iteración 863: Media = 4.89
# Iteración 864: Media = 4.92
# Iteración 865: Media = 4.97
# Iteración 866: Media = 4.96
# Iteración 867: Media = 4.86
# Iteración 868: Media = 4.90
# Iteración 869: Media = 4.97
# Iteración 870: Media = 4.89
# Iteración 871: Media = 4.96
# Iteración 872: Media = 5.02
# Iteración 873: Media = 5.01
# Iteración 874: Media = 4.91
# Iteración 875: Media = 4.91
# Iteración 876: Media = 4.97
# Iteración 877: Media = 4.88
# Iteración 878: Media = 4.91
# Iteración 879: Media = 4.95
# Iteración 880: Media = 4.92
# Iteración 881: Media = 5.00
# Iteración 882: Media = 4.90
# Iteración 883: Media = 5.03
# Iteración 884: Media = 4.94
# Iteración 885: Media = 4.89
# Iteración 886: Media = 4.96
# Iteración 887: Media = 4.94
# Iteración 888: Media = 4.97
# Iteración 889: Media = 4.92
# Iteración 890: Media = 4.88
# Iteración 891: Media = 4.92
# Iteración 892: Media = 5.06
# Iteración 893: Media = 4.97
# Iteración 894: Media = 4.97
# Iteración 895: Media = 4.93
# Iteración 896: Media = 4.97
# Iteración 897: Media = 4.99
# Iteración 898: Media = 4.93
# Iteración 899: Media = 4.97
# Iteración 900: Media = 4.91
# Iteración 901: Media = 4.87
# Iteración 902: Media = 5.04
# Iteración 903: Media = 4.95
# Iteración 904: Media = 4.97
# Iteración 905: Media = 4.91
# Iteración 906: Media = 4.96
# Iteración 907: Media = 5.00
# Iteración 908: Media = 5.01
# Iteración 909: Media = 5.00
# Iteración 910: Media = 5.02
# Iteración 911: Media = 4.98
# Iteración 912: Media = 4.99
# Iteración 913: Media = 4.98
# Iteración 914: Media = 4.93
# Iteración 915: Media = 4.93
# Iteración 916: Media = 4.94
# Iteración 917: Media = 5.04
# Iteración 918: Media = 4.93
# Iteración 919: Media = 4.96
# Iteración 920: Media = 4.90
# Iteración 921: Media = 4.96
# Iteración 922: Media = 4.95
# Iteración 923: Media = 5.00
# Iteración 924: Media = 5.01
# Iteración 925: Media = 4.93
# Iteración 926: Media = 4.91
# Iteración 927: Media = 4.94
# Iteración 928: Media = 4.93
# Iteración 929: Media = 4.91
# Iteración 930: Media = 5.01
# Iteración 931: Media = 4.89
# Iteración 932: Media = 4.91
# Iteración 933: Media = 4.94
# Iteración 934: Media = 4.98
# Iteración 935: Media = 4.97
# Iteración 936: Media = 4.97
# Iteración 937: Media = 4.92
# Iteración 938: Media = 4.99
# Iteración 939: Media = 4.97
# Iteración 940: Media = 4.93
# Iteración 941: Media = 4.89
# Iteración 942: Media = 4.96
# Iteración 943: Media = 4.95
# Iteración 944: Media = 4.96
# Iteración 945: Media = 4.94
# Iteración 946: Media = 4.93
# Iteración 947: Media = 4.97
# Iteración 948: Media = 4.98
# Iteración 949: Media = 4.89
# Iteración 950: Media = 5.00
# Iteración 951: Media = 4.92
# Iteración 952: Media = 4.94
# Iteración 953: Media = 4.84
# Iteración 954: Media = 4.97
# Iteración 955: Media = 4.86
# Iteración 956: Media = 4.95
# Iteración 957: Media = 4.96
# Iteración 958: Media = 4.97
# Iteración 959: Media = 5.00
# Iteración 960: Media = 5.01
# Iteración 961: Media = 4.94
# Iteración 962: Media = 5.00
# Iteración 963: Media = 4.99
# Iteración 964: Media = 4.92
# Iteración 965: Media = 4.96
# Iteración 966: Media = 4.95
# Iteración 967: Media = 4.97
# Iteración 968: Media = 5.03
# Iteración 969: Media = 4.94
# Iteración 970: Media = 4.93
# Iteración 971: Media = 4.93
# Iteración 972: Media = 4.98
# Iteración 973: Media = 4.98
# Iteración 974: Media = 4.89
# Iteración 975: Media = 4.98
# Iteración 976: Media = 5.04
# Iteración 977: Media = 4.98
# Iteración 978: Media = 4.95
# Iteración 979: Media = 5.02
# Iteración 980: Media = 4.97
# Iteración 981: Media = 5.00
# Iteración 982: Media = 4.99
# Iteración 983: Media = 4.93
# Iteración 984: Media = 4.98
# Iteración 985: Media = 4.98
# Iteración 986: Media = 4.93
# Iteración 987: Media = 4.95
# Iteración 988: Media = 5.00
# Iteración 989: Media = 4.95
# Iteración 990: Media = 4.97
# Iteración 991: Media = 4.96
# Iteración 992: Media = 4.91
# Iteración 993: Media = 4.93
# Iteración 994: Media = 4.93
# Iteración 995: Media = 4.95
# Iteración 996: Media = 4.98
# Iteración 997: Media = 4.97
# Iteración 998: Media = 4.91
# Iteración 999: Media = 4.92
# Iteración 1000: Media = 4.90
#
# Intervalo de confianza al 95% para la media de la longitud del sépalo: 4.88 - 5.03
